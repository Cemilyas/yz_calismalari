# %%
print("Merhaba İGÜ MYO YZ Dersi 10.10.2024") # YAPAY ZEKA DERSİ
# Out:
# Merhaba İGÜ MYO YZ Dersi 10.10.2024

# %%
import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan komuttur
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/YAPAY_ZEKA_DERSI')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/YAPAY_ZEKA_DERSI

# %%
import pandas as pd
# Cemil'in ders ve not bilgileri
data = {'Ders': ['Algoritma', 'BilgisayarProgramlama', 'Elektronik-2', 'AviyonikSistemler'], 'Not': [95, 100, 65, 90]}
#Veriyi bir DataFrame'e dönüştür
df = pd.DataFrame(data)
#En yüksek notu bul
en_yuksek_not = df['Not'].max()
print("En yüksek not:" , en_yuksek_not)
# Ortalama notu hesapla
ortalama_not = df['Not'].mean()
print("Ortalama not:", ortalama_not)
print(df.describe())
# Out:
# En yüksek not: 100
# Ortalama not: 87.5
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %%
import numpy as np
# Rastgele tanımlanan değerler - sıralaması olmayan
dizi = np.array([1, -55, 9, -23, 13, -21, 23, 37, 29, -6])

# Dizinin Ortalama sonuc
ortalama = np.mean(dizi)
print("Ortalama:", ortalama)

# Dizinin Standart sapma
std_sapma = np.std(dizi)
print("Standart Sapma:", std_sapma)

# Dizinin mutlağını al
mutlak_veriler = np.abs(dizi)
print("Mutlak Deger Cıktısı:", mutlak_veriler)
# Out:
# Ortalama: 0.7
# Standart Sapma: 26.487921775783015
# Mutlak Deger Cıktısı: [ 1 55  9 23 13 21 23 37 29  6]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100,)
y = np.sin(x)

plt.plot(x, y)
plt.title('Sinüs Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

# Satış grafiği çiz
plt.plot(yillar, satislar, marker='o')

# Grafik başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")


# Grafiği göster
plt.show()

# %%
import matplotlib.pyplot as plt

# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

# Satış grafiği çiz
plt.bar(yillar, satislar, color='skyblue')

# Grafik başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

# Grafiği göster
plt.show()

# %%
import matplotlib.pyplot as plt

# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

# Satış grafiği çiz
plt.barh(yillar, satislar, color='red')

# Grafik başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

# Grafiği göster
plt.show()

# %%
import matplotlib.pyplot as plt

# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

# Satış grafiği çiz
plt.scatter(yillar, satislar, color='black')

# Grafik başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

# Grafiği göster
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='YlOrRd')
plt.title('Dağılım Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.colorbar()  # Renk skalasını ekler
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 10, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='plasma')

ax.set_title('3D Yüzey Grafiği Örneği')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_colormaps():
    colormaps = plt.colormaps()
    n = len(colormaps)
    fig, axs = plt.subplots(n//2, 2, figsize=(10, 2*(n//2)))
    for ax, cmap_name in zip(axs.ravel(), colormaps):
        cmap = plt.get_cmap(cmap_name)
        img = np.linspace(0, 1, 256).reshape(1, -1)
        ax.imshow(img, aspect='auto', cmap=cmap)
        ax.set_title(cmap_name, fontsize=8)
        ax.set_axis_off()
    plt.show()

plot_colormaps()
