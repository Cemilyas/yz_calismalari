# %%
import pandas as pd


data = {"Çalışanlar": ["Cemil","Furkan","Halil","Emre"], "Mevki": ["Yazılım Mühendisi","Elektrik Mühendisi","Bakım Onarımcı","Donanımcı"], "Maaş": ["20.000","17500","15000","16500"]}
data_1 = pd.DataFrame(data)
data_1
# Out:
#   Çalışanlar               Mevki    Maaş
# 0      Cemil   Yazılım Mühendisi  20.000
# 1     Furkan  Elektrik Mühendisi   17500
# 2      Halil      Bakım Onarımcı   15000
# 3       Emre           Donanımcı   16500

# %%
data_1 = data_1.set_index("Çalışanlar")
data_1
# Out:
#                          Mevki    Maaş
# Çalışanlar
# Cemil        Yazılım Mühendisi  20.000
# Furkan      Elektrik Mühendisi   17500
# Halil           Bakım Onarımcı   15000
# Emre                 Donanımcı   16500

# %%
data_1["Maaş"]
# Out:
# Çalışanlar
# Cemil     20.000
# Furkan     17500
# Halil      15000
# Emre       16500
# Name: Maaş, dtype: object

# %%
maaş = data_1["Maaş"]
maaş
# Out:
# Çalışanlar
# Cemil     20.000
# Furkan     17500
# Halil      15000
# Emre       16500
# Name: Maaş, dtype: object

# %%
maaş.max()
# Out:
# '20.000'

# %%
maaş.min()
# Out:
# '15000'

# %%
maaş.Cemil
# Out:
# '20.000'

# %%
maaş.values
# Out:
# array(['20.000', '17500', '15000', '16500'], dtype=object)

# %%
maaş.describe()
# Out:
# count          4
# unique         4
# top       20.000
# freq           1
# Name: Maaş, dtype: object

# %%
maaş.count()
# Out:
# 4

# %%
data_1
# Out:
#                          Mevki    Maaş
# Çalışanlar
# Cemil        Yazılım Mühendisi  20.000
# Furkan      Elektrik Mühendisi   17500
# Halil           Bakım Onarımcı   15000
# Emre                 Donanımcı   16500

# %%
sıra = data_1["Mevki"][:1]
sıra
# Out:
# Çalışanlar
# Cemil    Yazılım Mühendisi
# Name: Mevki, dtype: object
